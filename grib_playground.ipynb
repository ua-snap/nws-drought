# %%
import xarray
import matplotlib.pyplot as plt

# %%
ds = xarray.load_dataset("./download.grib", engine="cfgrib")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 63, step: 12, latitude: 41, longitude: 41)
# Coordinates:
#     number      int64 0
#   * time        (time) datetime64[ns] 1979-12-31T18:00:00 ... 1980-01-31T18:0...
#   * step        (step) timedelta64[ns] 01:00:00 02:00:00 ... 11:00:00 12:00:00
#     surface     float64 0.0
#   * latitude    (latitude) float64 70.0 69.75 69.5 69.25 ... 60.5 60.25 60.0
#   * longitude   (longitude) float64 -140.0 -139.8 -139.5 ... -130.2 -130.0
#     valid_time  (time, step) datetime64[ns] 1979-12-31T19:00:00 ... 1980-02-0...
# Data variables:
#     tp          (time, step, latitude, longitude) float32 nan nan ... nan nan
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
# ...

# %%
ds.sel(time="1980-01-15T06:00:00.000000000", step="39600000000000").tp.plot()

# %%
ds.step
# Out:
# <xarray.DataArray 'step' (step: 12)>
# array([ 3600000000000,  7200000000000, 10800000000000, 14400000000000,
#        18000000000000, 21600000000000, 25200000000000, 28800000000000,
#        32400000000000, 36000000000000, 39600000000000, 43200000000000],
#       dtype='timedelta64[ns]')
# Coordinates:
#     number   int64 0
#   * step     (step) timedelta64[ns] 01:00:00 02:00:00 ... 11:00:00 12:00:00
#     surface  float64 0.0
# Attributes:
#     long_name:      time since forecast_reference_time
#     standard_name:  forecast_period
